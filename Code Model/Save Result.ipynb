# %%
import os
import cv2
import numpy as np
import pandas as pd
from keras.models import load_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the trained model
model = load_model('drive/MyDrive/Project_DAP391m_group2/Data/Data_detected/cheating_detection_model.h5')

# Create a list to store the results
results = []

# %%
# Define the directory containing the images you want to classify
image_directory = 'drive/MyDrive/Project_DAP391m_group2/Data/total_dataset/processed_dataset'

# %%
# Define a function to classify a single image
def classify_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, (256, 256))
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize the image
    result = model.predict(img)
    return "cheating" if result > 0.5 else "not cheating"

# %%
# Iterate over all images in the directory and classify them
for filename in os.listdir(image_directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(image_directory, filename)
        prediction = classify_image(image_path)
        results.append({'Image_Path': image_path, 'Classification': prediction})
# Out:
# ...
# 1/1 [==============================] - 0s 133ms/step

# %%
# Create a DataFrame from the results
result_df = pd.DataFrame(results)

# %%
# Export the results to an Excel file
result_df.to_excel('drive/MyDrive/Project_DAP391m_group2/Data/Data_detected/classification_results.xlsx', index=False)
